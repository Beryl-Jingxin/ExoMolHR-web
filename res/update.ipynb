# %%
import re
import os
import requests
import wikipedia
import pandas as pd
from pyvalem.formula import Formula

# %%
filenames = os.listdir('/home/jingxin/data/exomolhr/loc_result/')
molecules = []
molhtmls = []
moltags = []
molnames = []
molmasses = []
isoslugs = [] 
isoformulas = []
isohtmls = []
isotags = []
isomasses = []
datasets = []
for file in filenames:
    piece = file.replace('.csv','').replace('_p','+').replace('_m','-').split('__')
    
    # Molecule
    molecule = piece[0]
    molecules.append(molecule)
    molhtmls.append(Formula(molecule).html)
    moltags.append(molecule.lower())
    molmasses.append(format(Formula(molecule).mass, '.6f'))
    # Search molecule names from NIST website and Wikipedia.
    r_search = requests.get('https://webbook.nist.gov/cgi/cbook.cgi?Formula='
                            +molecule.replace('+','%2B')+'&NoIon=on&Units=SI')
    title = r_search.text.split('<title>')[1].split('</title>')[0]
    if title != 'Search Results':
        molname = title
    else:
        link_list = re.findall(r"(?<=href=\").+?(?=\")", r_search.text)
        urls = []
        for url in link_list:
            if url.split('ID=')[0] == '/cgi/cbook.cgi?':
                urls.append(url)
        r_cgi = requests.get('https://webbook.nist.gov'+urls[0])
        molname = r_cgi.text.split('<title>')[1].split('</title>')[0]
    if molname == molecule:
        molname = wikipedia.page(molecule, auto_suggest=False).title
    molnames.append(molname.capitalize())
    
    # Isotopologue
    isotopologue = piece[1]
    isoformula = piece[3]
    isoslugs.append(isotopologue)
    isoformulas.append(isoformula)
    isohtmls.append(Formula(isoformula).html)
    isotags.append(isotopologue.replace('-','').lower())
    isomasses.append(format(Formula(isoformula).mass, '.6f'))
    
    # Dataset
    datasets.append(piece[2])
    
pieces_df = pd.DataFrame({'filename':filenames, 
                          'molecule':molecules, 'molhtml':molhtmls, 'moltag':moltags, 'molhtml':molhtmls, 'molname':molnames, 'molmass':molmasses,
                          'isoslug':isoslugs, 'isoformula':isoformulas, 'isohtml':isohtmls, 'isotag':isotags, 'isomass':isomasses, 
                          'dataset':datasets}).sort_values(by=['moltag','isotag','dataset'])
pieces_df['id'] = pieces_df.reset_index().index+1
pieces_colnames = ['id', 'filename', 'molecule', 'molhtml', 'moltag', 'molname', 'molmass',
                   'isoslug', 'isoformula', 'isohtml', 'isotag', 'isohtml', 'isomass', 'dataset']
pieces_df = pieces_df[pieces_colnames]
pieces_df
# Out:
#     id                                      filename molecule  \
# 2    1       AlCl__27Al-35Cl__YNAT__(27Al)(35Cl).csv     AlCl
# 14   2       AlCl__27Al-37Cl__YNAT__(27Al)(37Cl).csv     AlCl
# 4    3           AlH__27Al-1H__AloHa__(27Al)(1H).csv      AlH
# 17   4           AlO__26Al-16O__ATP__(26Al)(16O).csv      AlO
# 13   5           AlO__27Al-16O__ATP__(27Al)(16O).csv      AlO
# 16   6           AlO__27Al-17O__ATP__(27Al)(17O).csv      AlO
# 18   7           AlO__27Al-18O__ATP__(27Al)(18O).csv      AlO
# 19   8                 C2__12C2__8states__(12C)2.csv       C2
# 20   9        C2H2__12C2-1H2__aCeTY__(12C)2(1H)2.csv     C2H2
# 9   10             CaH__40Ca-1H__XAB__(40Ca)(1H).csv      CaH
# 0   11        CN__12C-14N__Trihybrid__(12C)(14N).csv       CN
# 13                         AlO    alo      Aluminum monoxide   42.980538
# 16                         AlO    alo      Aluminum monoxide   42.980538
# 18                         AlO    alo      Aluminum monoxide   42.980538
# 19               C<sub>2</sub>     c2               Dicarbon   24.022000
# 20  C<sub>2</sub>H<sub>2</sub>   c2h2              Acetylene   26.038000
# 9                          CaH    cah    Calcium monohydride   41.086000
# 0                           CN     cn          Cyano radical   26.018000
# 41              CO<sub>2</sub>    co2         Carbon dioxide   44.009000
# 47             H<sub>2</sub>CO   h2co           Formaldehyde   30.026000
# 35              H<sub>2</sub>O    h2o                  Water   18.015000
# 1               H<sub>2</sub>S    h2s       Hydrogen sulfide   34.076000
# 40   H<sub>3</sub><sup>+</sup>    h3+     Trihydrogen cation    3.024000
# 34   H<sub>3</sub><sup>+</sup>    h3+     Trihydrogen cation    3.024000
# 39   H<sub>3</sub><sup>+</sup>    h3+     Trihydrogen cation    3.024000
# 15   H<sub>3</sub><sup>+</sup>    h3+     Trihydrogen cation    3.024000
# 36  H<sub>3</sub>O<sup>+</sup>   h3o+       Hydronium cation   19.023000
# 46                        LiOH   lioh      Lithium hydroxide   23.947000
# 33                        LiOH   lioh      Lithium hydroxide   23.947000
# 3                          MgH    mgh  Magnesium monohydride   25.313000
# 5                          MgH    mgh  Magnesium monohydride   25.313000
# 7                          MgH    mgh  Magnesium monohydride   25.313000
# 6                           NH     nh               Imidogen   15.015000
# 11                          NH     nh               Imidogen   15.015000
# 8                           NH     nh               Imidogen   15.015000
# 10                          NH     nh               Imidogen   15.015000
# 38              NH<sub>3</sub>    nh3                Ammonia   17.031000
# 12                          NO     no           Nitric oxide   30.006000
# 21                         SiN    sin        Silicon nitride   42.092000
# 22                         SiN    sin        Silicon nitride   42.092000
# 23                         SiN    sin        Silicon nitride   42.092000
# 24                         SiN    sin        Silicon nitride   42.092000
# 32                         SiO    sio       Silicon monoxide   44.084000
# 42                          SO     so        Sulfur monoxide   48.059000
# 37              SO<sub>2</sub>    so2         Sulfur dioxide   64.058000
# 25                         TiO    tio         Titanium oxide   63.866000
# 43                          YO     yo       Yttrium monoxide  104.904840
# 44                          YO     yo       Yttrium monoxide  104.904840
# 45                          YO     yo       Yttrium monoxide  104.904840
# 26                         ZrO    zro        Zirconium oxide  107.223000
# 27                         ZrO    zro        Zirconium oxide  107.223000
# 28                         ZrO    zro        Zirconium oxide  107.223000
# 29                         ZrO    zro        Zirconium oxide  107.223000
# 30                         ZrO    zro        Zirconium oxide  107.223000
# 31                         ZrO    zro        Zirconium oxide  107.223000
#
#         isoslug       isoformula  \
# 2     27Al-35Cl     (27Al)(35Cl)
# 14    27Al-37Cl     (27Al)(37Cl)
# 4       27Al-1H       (27Al)(1H)
# 17     26Al-16O      (26Al)(16O)
# 13     27Al-16O      (27Al)(16O)
# 16     27Al-17O      (27Al)(17O)
# 18     27Al-18O      (27Al)(18O)
# 19         12C2           (12C)2
# 20     12C2-1H2      (12C)2(1H)2
# 9       40Ca-1H       (40Ca)(1H)
# 0       12C-14N       (12C)(14N)
# 41     12C-16O2      (12C)(16O)2
# 47  1H2-12C-16O  (1H)2(12C)(16O)
# 39  <sup>2</sup>H<sub>2</sub><sup>1</sup>H<sup>+</...    5.036029       MiZo
# 15              <sup>2</sup>H<sub>3</sub><sup>+</sup>    6.042305       MiZo
# 36  <sup>1</sup>H<sub>3</sub><sup>16</sup>O<sup>+<...   19.018390       eXeL
# 46          <sup>6</sup>Li<sup>16</sup>O<sup>1</sup>H   23.017863       OYT7
# 33          <sup>7</sup>Li<sup>16</sup>O<sup>1</sup>H   24.018743       OYT7
# 3                        <sup>24</sup>Mg<sup>1</sup>H   24.992867        XAB
# 5                        <sup>25</sup>Mg<sup>1</sup>H   25.993662        XAB
# 7                        <sup>26</sup>Mg<sup>1</sup>H   26.990418        XAB
# 6                         <sup>14</sup>N<sup>1</sup>H   15.010899     kNigHt
# 11                        <sup>14</sup>N<sup>2</sup>H   16.017176     kNigHt
# 8                         <sup>15</sup>N<sup>1</sup>H   16.007934     kNigHt
# 10                        <sup>15</sup>N<sup>2</sup>H   17.014211     kNigHt
# 38            <sup>14</sup>N<sup>1</sup>H<sub>3</sub>   17.026549     CoYuTe
# 12                       <sup>14</sup>N<sup>16</sup>O   29.997989       XABC
# 21                      <sup>28</sup>Si<sup>14</sup>N   41.980001    SiNfull
# 22                      <sup>28</sup>Si<sup>15</sup>N   42.977035    SiNfull
# 23                      <sup>29</sup>Si<sup>14</sup>N   42.979569    SiNfull
# 24                      <sup>30</sup>Si<sup>14</sup>N   43.976844    SiNfull
# 32                      <sup>28</sup>Si<sup>16</sup>O   43.971841  SiOUVenIR
# 42                       <sup>32</sup>S<sup>16</sup>O   47.966986      SOLIS
# 37           <sup>32</sup>S<sup>16</sup>O<sub>2</sub>   63.961900    ExoAmes
# 25                      <sup>48</sup>Ti<sup>16</sup>O   63.942856       Toto
# 43                       <sup>89</sup>Y<sup>16</sup>O  104.900756      BRYTS
# 44                       <sup>89</sup>Y<sup>17</sup>O  105.904973      BRYTS
# 45                       <sup>89</sup>Y<sup>18</sup>O  106.905001      BRYTS
# 26                      <sup>90</sup>Zr<sup>16</sup>O  105.899613      ZorrO
# 27                      <sup>91</sup>Zr<sup>16</sup>O  106.900555      ZorrO
# 28                      <sup>92</sup>Zr<sup>16</sup>O  107.899950      ZorrO
# 29                      <sup>93</sup>Zr<sup>16</sup>O  108.901385      ZorrO
# 30                      <sup>94</sup>Zr<sup>16</sup>O  109.901227      ZorrO
# 31                      <sup>96</sup>Zr<sup>16</sup>O  111.903192      ZorrO

# %%
pieces_df.to_csv('~/ExoMolHR-web/res/exomolhr.csv', index=False, columns=pieces_colnames)

# %%
molecules_df = pieces_df[['molecule', 'molhtml', 'moltag', 'molname', 'molmass']].drop_duplicates().sort_values(by=['moltag'])
molecules_df['molid'] = molecules_df.reset_index().index+1
# molecules_df['molname'] = ['Aluminum monochloride', 'Aluminum hydride', 'Aluminum monoxide','Dicarbon', 'Acetylene', 
#                            'Calcium monohydride', 'Calcium monohydroxide', 'Cyano radical', 'Carbon dioxide', 'Formaldehyde ', 
#                            'Water', 'Hydrogen sulfide', 'Trihydrogen cation', 'Hydronium cation', 'Magnesium monohydride', 
#                            'Sodium oxide', 'Sodium hydroxide', 'Ammonia', 'Nitric oxide', 'Silicon nitride',
#                            'Silicon monoxide', 'Sulfur dioxide', 'Titanium oxide']
molecules_colnames = ['molid', 'molecule', 'molhtml', 'moltag', 'molname', 'molmass']
molecules_df = molecules_df[molecules_colnames]
molecules_df
# Out:
#     molid molecule                     molhtml moltag                molname  \
# 2       1     AlCl                        AlCl   alcl  Aluminum monochloride
# 4       2      AlH                         AlH    alh       Aluminum hydride
# 17      3      AlO                         AlO    alo      Aluminum monoxide
# 19      4       C2               C<sub>2</sub>     c2               Dicarbon
# 20      5     C2H2  C<sub>2</sub>H<sub>2</sub>   c2h2              Acetylene
# 9       6      CaH                         CaH    cah    Calcium monohydride
# 0       7       CN                          CN     cn          Cyano radical
# 41      8      CO2              CO<sub>2</sub>    co2         Carbon dioxide
# 47      9     H2CO             H<sub>2</sub>CO   h2co           Formaldehyde
# 35     10      H2O              H<sub>2</sub>O    h2o                  Water
# 1      11      H2S              H<sub>2</sub>S    h2s       Hydrogen sulfide
# 40     12      H3+   H<sub>3</sub><sup>+</sup>    h3+     Trihydrogen cation
# 36     13     H3O+  H<sub>3</sub>O<sup>+</sup>   h3o+       Hydronium cation
# 46     14     LiOH                        LiOH   lioh      Lithium hydroxide
# 3      15      MgH                         MgH    mgh  Magnesium monohydride
# 6      16       NH                          NH     nh               Imidogen
# 38     17      NH3              NH<sub>3</sub>    nh3                Ammonia
# 12     18       NO                          NO     no           Nitric oxide
# 21     19      SiN                         SiN    sin        Silicon nitride
# 32     20      SiO                         SiO    sio       Silicon monoxide
# 42     21       SO                          SO     so        Sulfur monoxide
# 37     22      SO2              SO<sub>2</sub>    so2         Sulfur dioxide
# 25     23      TiO                         TiO    tio         Titanium oxide
# 43     24       YO                          YO     yo       Yttrium monoxide
# 26     25      ZrO                         ZrO    zro        Zirconium oxide
#
#        molmass
# 2    62.431538
# 4    27.989538
# 17   42.980538
# 19   24.022000
# 20   26.038000
# 9    41.086000
# 0    26.018000
# 41   44.009000
# 47   30.026000
# 35   18.015000
# 1    34.076000
# 40    3.024000
# 36   19.023000
# 46   23.947000
# 3    25.313000
# 6    15.015000
# 38   17.031000
# 12   30.006000
# 21   42.092000
# 32   44.084000
# 42   48.059000
# 37   64.058000
# 25   63.866000
# 43  104.904840
# 26  107.223000

# %%
molecules_df.to_csv('~/ExoMolHR-web/res/molecules.csv', index=False, columns=molecules_colnames)

# %%
# isotopologues_df = pieces_df.loc[:, ['molecule', 'molhtml', 'molname', 
#                                      'isoslug', 'isoformula', 'isohtml', 'isotag', 'isomass', 
#                                      'dataset', 'filename']].drop_duplicates()
# isotopologues_df['id'] = isotopologues_df.reset_index().index+1
# isotopologues_colnames = ['id', 'molecule', 'molhtml', 'molname', 'isoslug', 'isoformula', 'isotag', 'isomass', 'dataset', 'filename']
# isotopologues_df = isotopologues_df[isotopologues_colnames]
# isotopologues_df.to_csv('~/ExoMolHR-web/res/isotopologues.csv', index=False, columns=isotopologues_colnames)
# isotopologues_df
# Out:
#     id molecule                     molhtml                molname  \
# 2    1     AlCl                        AlCl  Aluminum monochloride
# 16   2     AlCl                        AlCl  Aluminum monochloride
# 4    3      AlH                         AlH       Aluminum hydride
# 8    4      AlH                         AlH       Aluminum hydride
# 19   5      AlO                         AlO      Aluminum monoxide
# 15   6      AlO                         AlO      Aluminum monoxide
# 18   7      AlO                         AlO      Aluminum monoxide
# 20   8      AlO                         AlO      Aluminum monoxide
# 21   9       C2               C<sub>2</sub>               Dicarbon
# 22  10     C2H2  C<sub>2</sub>H<sub>2</sub>              Acetylene
# 10  11      CaH                         CaH    Calcium monohydride
# 0   12       CN                          CN          Cyano radical
# 47  13      CO2              CO<sub>2</sub>         Carbon dioxide
# 53  14     H2CO             H<sub>2</sub>CO           Formaldehyde
# 41  15      H2O              H<sub>2</sub>O                  Water
# 1   16      H2S              H<sub>2</sub>S       Hydrogen sulfide
# 46  17      H3+   H<sub>3</sub><sup>+</sup>     Trihydrogen cation
# 40  18      H3+   H<sub>3</sub><sup>+</sup>     Trihydrogen cation
# 45  19      H3+   H<sub>3</sub><sup>+</sup>     Trihydrogen cation
# 17  20      H3+   H<sub>3</sub><sup>+</sup>     Trihydrogen cation
# 42  21     H3O+  H<sub>3</sub>O<sup>+</sup>       Hydronium cation
# 52  22     LiOH                        LiOH      Lithium hydroxide
# 39  23     LiOH                        LiOH      Lithium hydroxide
# 3   24      MgH                         MgH  Magnesium monohydride
# 5   25      MgH                         MgH  Magnesium monohydride
# 7   26      MgH                         MgH  Magnesium monohydride
# 13  27      NaO                         NaO           Sodium oxide
# 6   28       NH                          NH               Imidogen
# 12  29       NH                          NH               Imidogen
# 9   30       NH                          NH               Imidogen
# 11  31       NH                          NH               Imidogen
# 44  32      NH3              NH<sub>3</sub>                Ammonia
# 14  33       NO                          NO           Nitric oxide
# 23  34      SiN                         SiN        Silicon nitride
# 24  35      SiN                         SiN        Silicon nitride
# 25  36      SiN                         SiN        Silicon nitride
# 26  37      SiN                         SiN        Silicon nitride
# 38  38      SiO                         SiO       Silicon monoxide
# 48  39       SO                          SO        Sulfur monoxide
# 43  40      SO2              SO<sub>2</sub>         Sulfur dioxide
# 27  41      TiO                         TiO         Titanium oxide
# 28  42      TiO                         TiO         Titanium oxide
# 29  43      TiO                         TiO         Titanium oxide
# 30  44      TiO                         TiO         Titanium oxide
# 31  45      TiO                         TiO         Titanium oxide
# 49  46       YO                          YO       Yttrium monoxide
# 50  47       YO                          YO       Yttrium monoxide
# 51  48       YO                          YO       Yttrium monoxide
# 32  49      ZrO                         ZrO        Zirconium oxide
# 33  50      ZrO                         ZrO        Zirconium oxide
# 34  51      ZrO                         ZrO        Zirconium oxide
# 35  52      ZrO                         ZrO        Zirconium oxide
# 36  53      ZrO                         ZrO        Zirconium oxide
# 37  54      ZrO                         ZrO        Zirconium oxide
#
#         isoslug       isoformula     isotag     isomass    dataset  \
# 2     27Al-35Cl     (27Al)(35Cl)   27al35cl   61.950391       YNAT
# 16    27Al-37Cl     (27Al)(37Cl)   27al37cl   63.947441       YNAT
# 4       27Al-1H       (27Al)(1H)     27al1h   27.989363      AloHa
# 8       27Al-2H       (27Al)(2H)     27al2h   28.995640      AloHa
# 19     26Al-16O      (26Al)(16O)    26al16o   41.981806        ATP
# 15     27Al-16O      (27Al)(16O)    27al16o   42.976453        ATP
# 33     91Zr-16O      (91Zr)(16O)    91zr16o  106.900555      ZorrO
# 34     92Zr-16O      (92Zr)(16O)    92zr16o  107.899950      ZorrO
# 35     93Zr-16O      (93Zr)(16O)    93zr16o  108.901385      ZorrO
# 36     94Zr-16O      (94Zr)(16O)    94zr16o  109.901227      ZorrO
# 37     96Zr-16O      (96Zr)(16O)    96zr16o  111.903192      ZorrO
#
#                                         filename
# 2        AlCl__27Al-35Cl__YNAT__(27Al)(35Cl).csv
# 16       AlCl__27Al-37Cl__YNAT__(27Al)(37Cl).csv
# 4            AlH__27Al-1H__AloHa__(27Al)(1H).csv
# 8            AlH__27Al-2H__AloHa__(27Al)(2H).csv
# 19           AlO__26Al-16O__ATP__(26Al)(16O).csv
# 15           AlO__27Al-16O__ATP__(27Al)(16O).csv
# 18           AlO__27Al-17O__ATP__(27Al)(17O).csv
# 20           AlO__27Al-18O__ATP__(27Al)(18O).csv
# 21                 C2__12C2__8states__(12C)2.csv
# 22        C2H2__12C2-1H2__aCeTY__(12C)2(1H)2.csv
# 10             CaH__40Ca-1H__XAB__(40Ca)(1H).csv
# 0         CN__12C-14N__Trihybrid__(12C)(14N).csv
# 47      CO2__12C-16O2__UCL-4000__(12C)(16O)2.csv
# 53  H2CO__1H2-12C-16O__AYTY__(1H)2(12C)(16O).csv
# 41       H2O__1H2-16O__POKAZATEL__(1H)2(16O).csv
# 1             H2S__1H2-32S__AYT2__(1H)2(32S).csv
# 46            H3_p__1H2-2H_p__ST__(1H)2(2H)+.csv
# 40              H3_p__1H3_p__MiZATeP__(1H)3+.csv
# 45          H3_p__2H2-1H_p__MiZo__(2H)2(1H)+.csv
# 17                 H3_p__2H3_p__MiZo__(2H)3+.csv
# 42       H3O_p__1H3-16O_p__eXeL__(1H)3(16O)+.csv
# 52    LiOH__6Li-16O-1H__OYT7__(6Li)(16O)(1H).csv
# 39    LiOH__7Li-16O-1H__OYT7__(7Li)(16O)(1H).csv
# 3              MgH__24Mg-1H__XAB__(24Mg)(1H).csv
# 5              MgH__25Mg-1H__XAB__(25Mg)(1H).csv
# 7              MgH__26Mg-1H__XAB__(26Mg)(1H).csv
# 13       NaO__23Na-16O__NaOUCMe__(23Na)(16O).csv
# 6              NH__14N-1H__kNigHt__(14N)(1H).csv
# 12             NH__14N-2H__kNigHt__(14N)(2H).csv
# 9              NH__15N-1H__kNigHt__(15N)(1H).csv
# 11             NH__15N-2H__kNigHt__(15N)(2H).csv
# 44          NH3__14N-1H3__CoYuTe__(14N)(1H)3.csv
# 14             NO__14N-16O__XABC__(14N)(16O).csv
# 23       SiN__28Si-14N__SiNfull__(28Si)(14N).csv
# 24       SiN__28Si-15N__SiNfull__(28Si)(15N).csv
# 25       SiN__29Si-14N__SiNfull__(29Si)(14N).csv
# 26       SiN__30Si-14N__SiNfull__(30Si)(14N).csv
# 38     SiO__28Si-16O__SiOUVenIR__(28Si)(16O).csv
# 48            SO__32S-16O__SOLIS__(32S)(16O).csv
# 43       SO2__32S-16O2__ExoAmes__(32S)(16O)2.csv
# 27          TiO__46Ti-16O__Toto__(46Ti)(16O).csv
# 28          TiO__47Ti-16O__Toto__(47Ti)(16O).csv
# 29          TiO__48Ti-16O__Toto__(48Ti)(16O).csv
# 30          TiO__49Ti-16O__Toto__(49Ti)(16O).csv
# 31          TiO__50Ti-16O__Toto__(50Ti)(16O).csv
# 49            YO__89Y-16O__BRYTS__(89Y)(16O).csv
# 50            YO__89Y-17O__BRYTS__(89Y)(17O).csv
# 51            YO__89Y-18O__BRYTS__(89Y)(18O).csv
# 32         ZrO__90Zr-16O__ZorrO__(90Zr)(16O).csv
# 33         ZrO__91Zr-16O__ZorrO__(91Zr)(16O).csv
# 34         ZrO__92Zr-16O__ZorrO__(92Zr)(16O).csv
# 35         ZrO__93Zr-16O__ZorrO__(93Zr)(16O).csv
# 36         ZrO__94Zr-16O__ZorrO__(94Zr)(16O).csv
# 37         ZrO__96Zr-16O__ZorrO__(96Zr)(16O).csv

# %%
molecule = 'CN'
isotopologues_df = pieces_df[pieces_df['molecule'].isin([molecule])]
isotopologues_df = isotopologues_df[['molecule', 'molhtml', 'molname', 
                                     'isoslug', 'isoformula', 'isohtml', 'isotag', 'isomass']].drop_duplicates()
isotopologues_df['id'] = isotopologues_df.reset_index().index+1
isotopologues_df
# Out:
#   molecule molhtml        molname  isoslug  isoformula  \
# 0       CN      CN  Cyano radical  12C-14N  (12C)(14N)
#
#                         isohtml                       isohtml  isotag  \
# 0  <sup>12</sup>C<sup>14</sup>N  <sup>12</sup>C<sup>14</sup>N  12c14n
#
#      isomass  id
# 0  26.003074   1

# %%
# molecule = 'CN'
# isotopologues_df = pd.read_csv('~/ExoMolHR-web/res/pieces.csv', header=0)
# isotopologues_df = isotopologues_df[isotopologues_df['molecule'].isin([molecule])].drop(columns=['id', 'dataset']).drop_duplicates()
# isotopologues_df['id'] = isotopologues_df.reset_index().index+1
# isotopologues_df = isotopologues_df[['id', 'molecule', 'molformula', 'molname', 'isoslug', 'isoformula', 'isotag', 'isomass']]
# isotopologues_df

# %%
molecule = 'CN'
isotopologue = '12C-14N'
datasets_df = pieces_df[pieces_df[['molecule', 'isoslug']].isin([molecule, isotopologue]).all(axis=1)]
datasets_df = datasets_df[['molecule', 'molhtml', 'molname', 
                           'isoslug', 'isoformula', 'isohtml', 'isotag', 'isomass',
                           'dataset', 'filename']].drop_duplicates()
datasets_df['id'] = datasets_df.reset_index().index+1
datasets_df
# Out:
#   molecule molhtml        molname  isoslug  isoformula  \
# 0       CN      CN  Cyano radical  12C-14N  (12C)(14N)
#
#                         isohtml                       isohtml  isotag  \
# 0  <sup>12</sup>C<sup>14</sup>N  <sup>12</sup>C<sup>14</sup>N  12c14n
#
#      isomass    dataset                                filename  id
# 0  26.003074  Trihybrid  CN__12C-14N__Trihybrid__(12C)(14N).csv   1

# %%
# molecule = 'CN'
# isotopologue = '12C-14N'
# dataset_df = pd.read_csv('~/ExoMolHR-web/res/isotopologues.csv', header=0)
# dataset_df = dataset_df[dataset_df[['molecule', 'isoslug']].isin([molecule, isotopologue]).all(axis=1)]
# dataset_df['id'] = dataset_df.reset_index().index+1
# dataset_df

# %%
list(datasets_df[datasets_df['isoslug'].isin([isotopologue])]['isoformula'])[0]
# Out:
# '(12C)(14N)'
